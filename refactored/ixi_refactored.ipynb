# %% [markdown]
# ### Sex Classification
# On the [Information eXtracion from Images](https://brain-development.org/ixi-dataset/) (IXI) dataset

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, confusion_matrix
from tqdm import tqdm
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import OneCycleLR
import gc
import matplotlib.pyplot as plt
from util import seed_everything, count_parameters
from networks import SpectralViT, SpatialViT, SpatialViTMatched, AttentionUNet, SwinTransformer
from data_loaders import load_ixi_data, BalancedDataset

# Configuration
MNI_DIR = os.path.expanduser('~/SpectralViT/data/IXI_extracted/')
CSV_PATH = os.path.expanduser('~/SpectralViT/data/IXI_extracted/IXI.csv')
VOL_SIZE = 96
N_COMP = 128
EPOCHS = 500
LR = 1e-4
BATCH_SIZE = 8
N_FOLDS = 5
device = torch.device("cuda:5" if torch.cuda.is_available() else "cpu")

seed_everything(0)

# %%
# Load data
X, Y = load_ixi_data(MNI_DIR, CSV_PATH, VOL_SIZE)
X_flat = X.reshape(len(X), -1)

print(f"Loaded {len(X)} samples")
print(f"Volume shape: {X.shape}")
print(f"Labels: {np.bincount(Y.astype(int))}")
kf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=0)
# Out:
# Loading Data:   0%|          | 0/581 [00:00<?, ?it/s]
# Loading Data: 100%|██████████| 581/581 [01:25<00:00,  6.80it/s]
# Loaded 566 samples
# Volume shape: (566, 96, 96, 96)
# Labels: [254 312]

# %%
# Spectral ViT
spectral_vit_history = {'spectral_vit_loss': []}
oof_probs_spec = []
oof_y_true = []

for fold, (train_idx, test_idx) in enumerate(kf.split(X_flat), 1):
    print(f"Starting Spectral ViT Fold {fold}...")
    torch.cuda.empty_cache()
    
    # Fit PCA on training data
    pca = PCA(n_components=N_COMP, whiten=True).fit(X_flat[train_idx])
    
    # Transform data
    tr_pca = torch.from_numpy(pca.transform(X_flat[train_idx])).float()
    tr_y = torch.from_numpy(Y[train_idx]).float()
    ts_pca = torch.from_numpy(pca.transform(X_flat[test_idx])).float().to(device)
    ts_y = torch.from_numpy(Y[test_idx]).float().to(device)
    
    loader = DataLoader(TensorDataset(tr_pca, tr_y), batch_size=BATCH_SIZE, shuffle=True)
    
    # Initialize model
    model = SpectralViT(n_inputs=N_COMP, embed_dim=16, use_mode_weights=True).to(device)
    opt = optim.AdamW(model.parameters(), lr=LR)
    sched = OneCycleLR(opt, max_lr=LR, steps_per_epoch=len(loader), epochs=EPOCHS)
    crit = nn.BCEWithLogitsLoss()
    
    # Training loop
    spectral_vit_fold_losses = []
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss_spectral_vit = 0
        for b_pca, b_y in loader:
            b_pca, b_y = b_pca.to(device), b_y.to(device)
            opt.zero_grad()
            loss = crit(model(b_pca), b_y)
            loss.backward()
            epoch_loss_spectral_vit += loss.item()
            opt.step()
            sched.step()

        if (epoch + 1) % 10 == 0:
            model.eval()
            with torch.no_grad():
                probs = torch.sigmoid(model(ts_pca)).cpu().numpy()
                auc = roc_auc_score(ts_y.cpu(), probs)
                preds = (probs > 0.5).astype(int)
                acc = np.mean(preds == ts_y.cpu().numpy()) * 100
                print(f"Fold {fold} | Epoch {epoch+1:3d} | Spec AUC: {auc:.4f} (Acc: {acc:.2f}%)")
                
        spectral_vit_fold_losses.append(epoch_loss_spectral_vit / len(loader))
    spectral_vit_history['spectral_vit_loss'].append(spectral_vit_fold_losses)

    
    # Final evaluation
    model.eval()
    with torch.no_grad():
        probs = torch.sigmoid(model(ts_pca)).cpu().numpy()
        oof_probs_spec.append(probs)
        oof_y_true.append(ts_y.cpu().numpy())

# Get parameter count
params_spec = count_parameters(model)
print(f"Spectral ViT parameters: {params_spec:,}")
# Out:
# Starting Spectral ViT Fold 1...
# Fold 1 | Epoch  10 | Spec AUC: 0.4873 (Acc: 60.53%)
# Fold 1 | Epoch  20 | Spec AUC: 0.5222 (Acc: 60.53%)
# Fold 1 | Epoch  30 | Spec AUC: 0.5694 (Acc: 60.53%)
# Fold 1 | Epoch  40 | Spec AUC: 0.6332 (Acc: 60.53%)
# Fold 1 | Epoch  50 | Spec AUC: 0.6899 (Acc: 60.53%)
# Fold 1 | Epoch  60 | Spec AUC: 0.7159 (Acc: 60.53%)
# Fold 1 | Epoch  70 | Spec AUC: 0.7742 (Acc: 66.67%)
# Fold 1 | Epoch  80 | Spec AUC: 0.8573 (Acc: 78.07%)
# Fold 1 | Epoch  90 | Spec AUC: 0.8776 (Acc: 81.58%)
# Fold 1 | Epoch 100 | Spec AUC: 0.8837 (Acc: 82.46%)
# Fold 1 | Epoch 110 | Spec AUC: 0.8963 (Acc: 81.58%)
# Fold 1 | Epoch 120 | Spec AUC: 0.8857 (Acc: 84.21%)
# Fold 1 | Epoch 130 | Spec AUC: 0.8976 (Acc: 83.33%)
# Fold 1 | Epoch 140 | Spec AUC: 0.8921 (Acc: 84.21%)
# Fold 1 | Epoch 150 | Spec AUC: 0.8966 (Acc: 83.33%)
# Fold 1 | Epoch 160 | Spec AUC: 0.8957 (Acc: 84.21%)
# Fold 1 | Epoch 170 | Spec AUC: 0.8924 (Acc: 79.82%)
# Fold 1 | Epoch 180 | Spec AUC: 0.8957 (Acc: 83.33%)
# Fold 1 | Epoch 190 | Spec AUC: 0.8989 (Acc: 79.82%)
# Fold 1 | Epoch 200 | Spec AUC: 0.8792 (Acc: 75.44%)
# Fold 1 | Epoch 210 | Spec AUC: 0.8924 (Acc: 81.58%)
# Fold 1 | Epoch 220 | Spec AUC: 0.9037 (Acc: 81.58%)
# Fold 1 | Epoch 230 | Spec AUC: 0.8779 (Acc: 75.44%)
# Fold 1 | Epoch 240 | Spec AUC: 0.8879 (Acc: 80.70%)
# Fold 1 | Epoch 250 | Spec AUC: 0.8680 (Acc: 83.33%)
# Fold 1 | Epoch 260 | Spec AUC: 0.8767 (Acc: 81.58%)
# Fold 1 | Epoch 270 | Spec AUC: 0.8841 (Acc: 79.82%)
# Fold 1 | Epoch 280 | Spec AUC: 0.8866 (Acc: 78.95%)
# Fold 1 | Epoch 290 | Spec AUC: 0.8712 (Acc: 82.46%)
# Fold 1 | Epoch 300 | Spec AUC: 0.8957 (Acc: 60.53%)
# Fold 1 | Epoch 310 | Spec AUC: 0.8834 (Acc: 82.46%)
# Fold 1 | Epoch 320 | Spec AUC: 0.8876 (Acc: 83.33%)
# Fold 1 | Epoch 330 | Spec AUC: 0.8805 (Acc: 81.58%)
# Fold 1 | Epoch 340 | Spec AUC: 0.8776 (Acc: 78.07%)
# Fold 1 | Epoch 350 | Spec AUC: 0.8857 (Acc: 82.46%)
# Fold 1 | Epoch 360 | Spec AUC: 0.8911 (Acc: 83.33%)
# Fold 1 | Epoch 370 | Spec AUC: 0.8747 (Acc: 82.46%)
# Fold 1 | Epoch 380 | Spec AUC: 0.8915 (Acc: 85.09%)
# Fold 1 | Epoch 390 | Spec AUC: 0.8911 (Acc: 85.09%)
# Fold 1 | Epoch 400 | Spec AUC: 0.8834 (Acc: 84.21%)
# Fold 1 | Epoch 410 | Spec AUC: 0.8821 (Acc: 83.33%)
# Fold 1 | Epoch 420 | Spec AUC: 0.8789 (Acc: 83.33%)
# Fold 1 | Epoch 430 | Spec AUC: 0.8870 (Acc: 85.09%)
# Fold 1 | Epoch 440 | Spec AUC: 0.8805 (Acc: 84.21%)
# Fold 1 | Epoch 450 | Spec AUC: 0.8789 (Acc: 83.33%)
# Fold 1 | Epoch 460 | Spec AUC: 0.8792 (Acc: 83.33%)
# Fold 1 | Epoch 470 | Spec AUC: 0.8805 (Acc: 83.33%)
# Fold 1 | Epoch 480 | Spec AUC: 0.8799 (Acc: 83.33%)
# Fold 1 | Epoch 490 | Spec AUC: 0.8779 (Acc: 83.33%)
# Fold 1 | Epoch 500 | Spec AUC: 0.8779 (Acc: 83.33%)
# Starting Spectral ViT Fold 2...
# Fold 2 | Epoch  10 | Spec AUC: 0.5144 (Acc: 57.52%)
# Fold 2 | Epoch  20 | Spec AUC: 0.5343 (Acc: 57.52%)
# Fold 2 | Epoch  30 | Spec AUC: 0.5619 (Acc: 57.52%)
# Fold 2 | Epoch  40 | Spec AUC: 0.6099 (Acc: 57.52%)
# Fold 2 | Epoch  50 | Spec AUC: 0.6865 (Acc: 57.52%)
# Fold 2 | Epoch  60 | Spec AUC: 0.8032 (Acc: 60.18%)
# Fold 2 | Epoch  70 | Spec AUC: 0.8599 (Acc: 76.99%)
# Fold 2 | Epoch  80 | Spec AUC: 0.8811 (Acc: 72.57%)
# Fold 2 | Epoch  90 | Spec AUC: 0.8798 (Acc: 78.76%)
# Fold 2 | Epoch 100 | Spec AUC: 0.8888 (Acc: 78.76%)
# Fold 2 | Epoch 110 | Spec AUC: 0.8872 (Acc: 76.99%)
# Fold 2 | Epoch 120 | Spec AUC: 0.8920 (Acc: 77.88%)
# Fold 2 | Epoch 130 | Spec AUC: 0.8901 (Acc: 82.30%)
# Fold 2 | Epoch 140 | Spec AUC: 0.9045 (Acc: 81.42%)
# Fold 2 | Epoch 150 | Spec AUC: 0.8939 (Acc: 83.19%)
# Fold 2 | Epoch 160 | Spec AUC: 0.9029 (Acc: 82.30%)
# Fold 2 | Epoch 170 | Spec AUC: 0.8965 (Acc: 82.30%)
# Fold 2 | Epoch 180 | Spec AUC: 0.8952 (Acc: 80.53%)
# Fold 2 | Epoch 190 | Spec AUC: 0.8910 (Acc: 81.42%)
# Fold 2 | Epoch 200 | Spec AUC: 0.8997 (Acc: 81.42%)
# Fold 2 | Epoch 210 | Spec AUC: 0.8862 (Acc: 76.99%)
# Fold 2 | Epoch 220 | Spec AUC: 0.8824 (Acc: 80.53%)
# Fold 2 | Epoch 230 | Spec AUC: 0.8929 (Acc: 81.42%)
# Fold 2 | Epoch 240 | Spec AUC: 0.8785 (Acc: 82.30%)
# Fold 2 | Epoch 250 | Spec AUC: 0.8862 (Acc: 80.53%)
# Fold 2 | Epoch 260 | Spec AUC: 0.8801 (Acc: 81.42%)
# Fold 2 | Epoch 270 | Spec AUC: 0.8702 (Acc: 81.42%)
# Fold 2 | Epoch 280 | Spec AUC: 0.8888 (Acc: 77.88%)
# Fold 2 | Epoch 290 | Spec AUC: 0.8843 (Acc: 79.65%)
# Fold 2 | Epoch 300 | Spec AUC: 0.8740 (Acc: 79.65%)
# Fold 2 | Epoch 310 | Spec AUC: 0.8772 (Acc: 80.53%)
# Fold 2 | Epoch 320 | Spec AUC: 0.8776 (Acc: 81.42%)
# Fold 2 | Epoch 330 | Spec AUC: 0.8673 (Acc: 80.53%)
# Fold 2 | Epoch 340 | Spec AUC: 0.8720 (Acc: 79.65%)
# Fold 2 | Epoch 350 | Spec AUC: 0.8705 (Acc: 80.53%)
# Fold 2 | Epoch 360 | Spec AUC: 0.8647 (Acc: 81.42%)
# Fold 2 | Epoch 370 | Spec AUC: 0.8628 (Acc: 80.53%)
# Fold 2 | Epoch 380 | Spec AUC: 0.8663 (Acc: 81.42%)
# Fold 2 | Epoch 390 | Spec AUC: 0.8615 (Acc: 81.42%)
# Fold 2 | Epoch 400 | Spec AUC: 0.8606 (Acc: 82.30%)
# Fold 2 | Epoch 410 | Spec AUC: 0.8590 (Acc: 81.42%)
# Fold 2 | Epoch 420 | Spec AUC: 0.8561 (Acc: 81.42%)
# Fold 2 | Epoch 430 | Spec AUC: 0.8574 (Acc: 83.19%)
# Fold 2 | Epoch 440 | Spec AUC: 0.8522 (Acc: 82.30%)
# Fold 2 | Epoch 450 | Spec AUC: 0.8564 (Acc: 82.30%)
# Fold 2 | Epoch 460 | Spec AUC: 0.8551 (Acc: 81.42%)
# Fold 2 | Epoch 470 | Spec AUC: 0.8551 (Acc: 82.30%)
# Fold 2 | Epoch 480 | Spec AUC: 0.8564 (Acc: 81.42%)
# Fold 2 | Epoch 490 | Spec AUC: 0.8554 (Acc: 82.30%)
# Fold 2 | Epoch 500 | Spec AUC: 0.8545 (Acc: 82.30%)
# Starting Spectral ViT Fold 3...
# Fold 3 | Epoch  10 | Spec AUC: 0.5947 (Acc: 51.33%)
# Fold 3 | Epoch  20 | Spec AUC: 0.6204 (Acc: 51.33%)
# Fold 3 | Epoch  30 | Spec AUC: 0.6759 (Acc: 51.33%)
# Fold 3 | Epoch  40 | Spec AUC: 0.7458 (Acc: 51.33%)
# Fold 3 | Epoch  50 | Spec AUC: 0.8433 (Acc: 51.33%)
# Fold 3 | Epoch  60 | Spec AUC: 0.8925 (Acc: 51.33%)
# Fold 3 | Epoch  70 | Spec AUC: 0.9107 (Acc: 69.03%)
# Fold 3 | Epoch  80 | Spec AUC: 0.9310 (Acc: 84.96%)
# Fold 3 | Epoch  90 | Spec AUC: 0.9364 (Acc: 83.19%)
# Fold 3 | Epoch 100 | Spec AUC: 0.9461 (Acc: 87.61%)
# Fold 3 | Epoch 110 | Spec AUC: 0.9492 (Acc: 90.27%)
# Fold 3 | Epoch 120 | Spec AUC: 0.9517 (Acc: 91.15%)
# Fold 3 | Epoch 130 | Spec AUC: 0.9458 (Acc: 79.65%)
# Fold 3 | Epoch 140 | Spec AUC: 0.9495 (Acc: 90.27%)
# Fold 3 | Epoch 150 | Spec AUC: 0.9524 (Acc: 87.61%)
# Fold 3 | Epoch 160 | Spec AUC: 0.9495 (Acc: 90.27%)
# Fold 3 | Epoch 170 | Spec AUC: 0.9423 (Acc: 79.65%)
# Fold 3 | Epoch 180 | Spec AUC: 0.9461 (Acc: 89.38%)
# Fold 3 | Epoch 190 | Spec AUC: 0.9458 (Acc: 82.30%)
# Fold 3 | Epoch 200 | Spec AUC: 0.9439 (Acc: 86.73%)
# Fold 3 | Epoch 210 | Spec AUC: 0.9442 (Acc: 87.61%)
# Fold 3 | Epoch 220 | Spec AUC: 0.9408 (Acc: 86.73%)
# Fold 3 | Epoch 230 | Spec AUC: 0.9461 (Acc: 88.50%)
# Fold 3 | Epoch 240 | Spec AUC: 0.9335 (Acc: 84.07%)
# Fold 3 | Epoch 250 | Spec AUC: 0.9310 (Acc: 77.88%)
# Fold 3 | Epoch 260 | Spec AUC: 0.9395 (Acc: 87.61%)
# Fold 3 | Epoch 270 | Spec AUC: 0.9041 (Acc: 78.76%)
# Fold 3 | Epoch 280 | Spec AUC: 0.9266 (Acc: 79.65%)
# Fold 3 | Epoch 290 | Spec AUC: 0.9376 (Acc: 81.42%)
# Fold 3 | Epoch 300 | Spec AUC: 0.9185 (Acc: 77.88%)
# Fold 3 | Epoch 310 | Spec AUC: 0.9348 (Acc: 82.30%)
# Fold 3 | Epoch 320 | Spec AUC: 0.9248 (Acc: 79.65%)
# Fold 3 | Epoch 330 | Spec AUC: 0.9292 (Acc: 78.76%)
# Fold 3 | Epoch 340 | Spec AUC: 0.9194 (Acc: 79.65%)
# Fold 3 | Epoch 350 | Spec AUC: 0.9169 (Acc: 78.76%)
# Fold 3 | Epoch 360 | Spec AUC: 0.9282 (Acc: 78.76%)
# Fold 3 | Epoch 370 | Spec AUC: 0.9373 (Acc: 78.76%)
# Fold 3 | Epoch 380 | Spec AUC: 0.9226 (Acc: 78.76%)
# Fold 3 | Epoch 390 | Spec AUC: 0.9260 (Acc: 77.88%)
# Fold 3 | Epoch 400 | Spec AUC: 0.9154 (Acc: 77.88%)
# Fold 3 | Epoch 410 | Spec AUC: 0.9138 (Acc: 77.88%)
# Fold 3 | Epoch 420 | Spec AUC: 0.9047 (Acc: 78.76%)
# Fold 3 | Epoch 430 | Spec AUC: 0.9091 (Acc: 78.76%)
# Fold 3 | Epoch 440 | Spec AUC: 0.8966 (Acc: 78.76%)
# Fold 3 | Epoch 450 | Spec AUC: 0.9232 (Acc: 79.65%)
# Fold 3 | Epoch 460 | Spec AUC: 0.9009 (Acc: 78.76%)
# Fold 3 | Epoch 470 | Spec AUC: 0.9163 (Acc: 78.76%)
# Fold 3 | Epoch 480 | Spec AUC: 0.8953 (Acc: 78.76%)
# Fold 3 | Epoch 490 | Spec AUC: 0.9016 (Acc: 78.76%)
# Fold 3 | Epoch 500 | Spec AUC: 0.9028 (Acc: 78.76%)
# Starting Spectral ViT Fold 4...
# Fold 4 | Epoch  10 | Spec AUC: 0.5453 (Acc: 56.64%)
# Fold 4 | Epoch  20 | Spec AUC: 0.5612 (Acc: 56.64%)
# Fold 4 | Epoch  30 | Spec AUC: 0.5896 (Acc: 56.64%)
# Fold 4 | Epoch  40 | Spec AUC: 0.6355 (Acc: 56.64%)
# Fold 4 | Epoch  50 | Spec AUC: 0.7047 (Acc: 56.64%)
# Fold 4 | Epoch  60 | Spec AUC: 0.7688 (Acc: 56.64%)
# Fold 4 | Epoch  70 | Spec AUC: 0.8428 (Acc: 53.98%)
# Fold 4 | Epoch  80 | Spec AUC: 0.8536 (Acc: 78.76%)
# Fold 4 | Epoch  90 | Spec AUC: 0.8543 (Acc: 76.99%)
# Fold 4 | Epoch 100 | Spec AUC: 0.8581 (Acc: 79.65%)
# Fold 4 | Epoch 110 | Spec AUC: 0.8540 (Acc: 62.83%)
# Fold 4 | Epoch 120 | Spec AUC: 0.8415 (Acc: 71.68%)
# Fold 4 | Epoch 130 | Spec AUC: 0.8485 (Acc: 79.65%)
# Fold 4 | Epoch 140 | Spec AUC: 0.8460 (Acc: 74.34%)
# Fold 4 | Epoch 150 | Spec AUC: 0.8508 (Acc: 74.34%)
# Fold 4 | Epoch 160 | Spec AUC: 0.8418 (Acc: 80.53%)
# Fold 4 | Epoch 170 | Spec AUC: 0.8485 (Acc: 79.65%)
# Fold 4 | Epoch 180 | Spec AUC: 0.8514 (Acc: 75.22%)
# Fold 4 | Epoch 190 | Spec AUC: 0.8479 (Acc: 79.65%)
# Fold 4 | Epoch 200 | Spec AUC: 0.8409 (Acc: 68.14%)
# Fold 4 | Epoch 210 | Spec AUC: 0.8367 (Acc: 80.53%)
# Fold 4 | Epoch 220 | Spec AUC: 0.8460 (Acc: 79.65%)
# Fold 4 | Epoch 230 | Spec AUC: 0.8377 (Acc: 80.53%)
# Fold 4 | Epoch 240 | Spec AUC: 0.8457 (Acc: 76.99%)
# Fold 4 | Epoch 250 | Spec AUC: 0.8453 (Acc: 77.88%)
# Fold 4 | Epoch 260 | Spec AUC: 0.8355 (Acc: 77.88%)
# Fold 4 | Epoch 270 | Spec AUC: 0.8450 (Acc: 79.65%)
# Fold 4 | Epoch 280 | Spec AUC: 0.8300 (Acc: 81.42%)
# Fold 4 | Epoch 290 | Spec AUC: 0.8154 (Acc: 80.53%)
# Fold 4 | Epoch 300 | Spec AUC: 0.8138 (Acc: 79.65%)
# Fold 4 | Epoch 310 | Spec AUC: 0.8163 (Acc: 80.53%)
# Fold 4 | Epoch 320 | Spec AUC: 0.8131 (Acc: 78.76%)
# Fold 4 | Epoch 330 | Spec AUC: 0.8186 (Acc: 78.76%)
# Fold 4 | Epoch 340 | Spec AUC: 0.8224 (Acc: 79.65%)
# Fold 4 | Epoch 350 | Spec AUC: 0.8259 (Acc: 79.65%)
# Fold 4 | Epoch 360 | Spec AUC: 0.8205 (Acc: 77.88%)
# Fold 4 | Epoch 370 | Spec AUC: 0.8326 (Acc: 80.53%)
# Fold 4 | Epoch 380 | Spec AUC: 0.8253 (Acc: 79.65%)
# Fold 4 | Epoch 390 | Spec AUC: 0.8114 (Acc: 78.76%)
# Fold 4 | Epoch 400 | Spec AUC: 0.8084 (Acc: 79.65%)
# Fold 4 | Epoch 410 | Spec AUC: 0.8157 (Acc: 79.65%)
# Fold 4 | Epoch 420 | Spec AUC: 0.8146 (Acc: 79.65%)
# Fold 4 | Epoch 430 | Spec AUC: 0.8138 (Acc: 80.53%)
# Fold 4 | Epoch 440 | Spec AUC: 0.8128 (Acc: 80.53%)
# Fold 4 | Epoch 450 | Spec AUC: 0.8135 (Acc: 79.65%)
# Fold 4 | Epoch 460 | Spec AUC: 0.8128 (Acc: 80.53%)
# Fold 4 | Epoch 470 | Spec AUC: 0.8109 (Acc: 80.53%)
# Fold 4 | Epoch 480 | Spec AUC: 0.8119 (Acc: 80.53%)
# Fold 4 | Epoch 490 | Spec AUC: 0.8112 (Acc: 80.53%)
# Fold 4 | Epoch 500 | Spec AUC: 0.8112 (Acc: 80.53%)
# Starting Spectral ViT Fold 5...
# Fold 5 | Epoch  10 | Spec AUC: 0.5122 (Acc: 49.56%)
# Fold 5 | Epoch  20 | Spec AUC: 0.5526 (Acc: 49.56%)
# Fold 5 | Epoch  30 | Spec AUC: 0.6156 (Acc: 49.56%)
# Fold 5 | Epoch  40 | Spec AUC: 0.7146 (Acc: 49.56%)
# Fold 5 | Epoch  50 | Spec AUC: 0.7885 (Acc: 49.56%)
# Fold 5 | Epoch  60 | Spec AUC: 0.7641 (Acc: 52.21%)
# Fold 5 | Epoch  70 | Spec AUC: 0.7691 (Acc: 68.14%)
# Fold 5 | Epoch  80 | Spec AUC: 0.8311 (Acc: 76.99%)
# Fold 5 | Epoch  90 | Spec AUC: 0.8637 (Acc: 75.22%)
# Fold 5 | Epoch 100 | Spec AUC: 0.8747 (Acc: 76.99%)
# Fold 5 | Epoch 110 | Spec AUC: 0.8813 (Acc: 76.11%)
# Fold 5 | Epoch 120 | Spec AUC: 0.8919 (Acc: 74.34%)
# Fold 5 | Epoch 130 | Spec AUC: 0.8841 (Acc: 77.88%)
# Fold 5 | Epoch 140 | Spec AUC: 0.8907 (Acc: 76.11%)
# Fold 5 | Epoch 150 | Spec AUC: 0.9023 (Acc: 80.53%)
# Fold 5 | Epoch 160 | Spec AUC: 0.8916 (Acc: 74.34%)
# Fold 5 | Epoch 170 | Spec AUC: 0.8997 (Acc: 77.88%)
# Fold 5 | Epoch 180 | Spec AUC: 0.9107 (Acc: 77.88%)
# Fold 5 | Epoch 190 | Spec AUC: 0.9063 (Acc: 80.53%)
# Fold 5 | Epoch 200 | Spec AUC: 0.9013 (Acc: 79.65%)
# Fold 5 | Epoch 210 | Spec AUC: 0.9044 (Acc: 80.53%)
# Fold 5 | Epoch 220 | Spec AUC: 0.9013 (Acc: 79.65%)
# Fold 5 | Epoch 230 | Spec AUC: 0.8810 (Acc: 78.76%)
# Fold 5 | Epoch 240 | Spec AUC: 0.8976 (Acc: 79.65%)
# Fold 5 | Epoch 250 | Spec AUC: 0.8885 (Acc: 77.88%)
# Fold 5 | Epoch 260 | Spec AUC: 0.8916 (Acc: 78.76%)
# Fold 5 | Epoch 270 | Spec AUC: 0.8766 (Acc: 79.65%)
# Fold 5 | Epoch 280 | Spec AUC: 0.8759 (Acc: 78.76%)
# Fold 5 | Epoch 290 | Spec AUC: 0.8722 (Acc: 78.76%)
# Fold 5 | Epoch 300 | Spec AUC: 0.8669 (Acc: 79.65%)
# Fold 5 | Epoch 310 | Spec AUC: 0.8571 (Acc: 76.99%)
# Fold 5 | Epoch 320 | Spec AUC: 0.8581 (Acc: 78.76%)
# Fold 5 | Epoch 330 | Spec AUC: 0.8656 (Acc: 79.65%)
# Fold 5 | Epoch 340 | Spec AUC: 0.8596 (Acc: 77.88%)
# Fold 5 | Epoch 350 | Spec AUC: 0.8515 (Acc: 76.99%)
# Fold 5 | Epoch 360 | Spec AUC: 0.8568 (Acc: 77.88%)
# Fold 5 | Epoch 370 | Spec AUC: 0.8362 (Acc: 76.99%)
# Fold 5 | Epoch 380 | Spec AUC: 0.8493 (Acc: 77.88%)
# Fold 5 | Epoch 390 | Spec AUC: 0.8521 (Acc: 76.99%)
# Fold 5 | Epoch 400 | Spec AUC: 0.8377 (Acc: 77.88%)
# Fold 5 | Epoch 410 | Spec AUC: 0.8258 (Acc: 76.11%)
# Fold 5 | Epoch 420 | Spec AUC: 0.8330 (Acc: 77.88%)
# Fold 5 | Epoch 430 | Spec AUC: 0.8346 (Acc: 76.99%)
# Fold 5 | Epoch 440 | Spec AUC: 0.8343 (Acc: 76.11%)
# Fold 5 | Epoch 450 | Spec AUC: 0.8336 (Acc: 76.99%)
# Fold 5 | Epoch 460 | Spec AUC: 0.8271 (Acc: 76.99%)
# Fold 5 | Epoch 470 | Spec AUC: 0.8214 (Acc: 77.88%)
# Fold 5 | Epoch 480 | Spec AUC: 0.8343 (Acc: 77.88%)
# Fold 5 | Epoch 490 | Spec AUC: 0.8324 (Acc: 78.76%)
# Fold 5 | Epoch 500 | Spec AUC: 0.8321 (Acc: 76.99%)
# Spectral ViT parameters: 13,169

# %%
# Spatial ViT
PHYSICAL_BATCH_SIZE = 2
EFFECTIVE_BATCH_SIZE = 8
ACCUMULATION_STEPS = EFFECTIVE_BATCH_SIZE // PHYSICAL_BATCH_SIZE

spatial_vit_history = {'spatial_vit_loss': []}
oof_probs_spat = []

for fold, (train_idx, test_idx) in enumerate(kf.split(X), 1):
    print(f"Starting Spatial ViT Fold {fold}...")
    torch.cuda.empty_cache()
    
    tr_vol = torch.from_numpy(X[train_idx]).unsqueeze(1).float()
    tr_y = torch.from_numpy(Y[train_idx]).float()
    ts_vol = torch.from_numpy(X[test_idx]).unsqueeze(1).float().to(device)
    ts_y = torch.from_numpy(Y[test_idx]).float().to(device)
    
    loader = DataLoader(TensorDataset(tr_vol, tr_y), batch_size=PHYSICAL_BATCH_SIZE, shuffle=True)
    
    model = SpatialViT(vol_size=VOL_SIZE, patch_size=12).to(device)
    opt = optim.AdamW(model.parameters(), lr=LR)
    sched = OneCycleLR(opt, max_lr=LR, steps_per_epoch=len(loader)//ACCUMULATION_STEPS, epochs=EPOCHS)
    crit = nn.BCEWithLogitsLoss()
    
    spatial_vit_fold_losses = []
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss_spatial_vit = 0
        for i, (b_vol, b_y) in enumerate(loader):
            b_vol, b_y = b_vol.to(device), b_y.to(device)
            logits = model(b_vol)
            loss = crit(logits, b_y) / ACCUMULATION_STEPS
            loss.backward()
            epoch_loss_spatial_vit += loss.item() * ACCUMULATION_STEPS

            if (i + 1) % ACCUMULATION_STEPS == 0:
                opt.step()
                sched.step()
                opt.zero_grad()
                
        if (epoch + 1) % 10 == 0:
            model.eval()
            with torch.no_grad():
                test_probs = []
                for chunk in torch.split(ts_vol, PHYSICAL_BATCH_SIZE):
                    test_probs.append(torch.sigmoid(model(chunk)))
                probs = torch.cat(test_probs).cpu().numpy()
                auc = roc_auc_score(ts_y.cpu(), probs)
                acc = np.mean((probs > 0.5) == ts_y.cpu().numpy()) * 100
                print(f"Fold {fold} | Epoch {epoch+1:3d} | Spat AUC: {auc:.4f} (Acc: {acc:.2f}%)")
        spatial_vit_fold_losses.append(epoch_loss_spatial_vit / len(loader))
    spatial_vit_history['spatial_vit_loss'].append(spatial_vit_fold_losses)
    
    model.eval()
    with torch.no_grad():
        test_probs = []
        for chunk in torch.split(ts_vol, PHYSICAL_BATCH_SIZE):
            test_probs.append(torch.sigmoid(model(chunk)))
        oof_probs_spat.append(torch.cat(test_probs).cpu().numpy())

params_spat = count_parameters(model)
print(f"Spatial ViT parameters: {params_spat:,}")
# Out:
# Starting Spatial ViT Fold 1...
# Fold 1 | Epoch  10 | Spat AUC: 0.6560 (Acc: 62.28%)
# Fold 1 | Epoch  20 | Spat AUC: 0.8077 (Acc: 60.53%)
# Fold 1 | Epoch  30 | Spat AUC: 0.7037 (Acc: 57.02%)
# Fold 1 | Epoch  40 | Spat AUC: 0.7395 (Acc: 64.04%)
# Fold 1 | Epoch  50 | Spat AUC: 0.7597 (Acc: 65.79%)
# Fold 1 | Epoch  60 | Spat AUC: 0.7965 (Acc: 71.05%)
# Fold 1 | Epoch  70 | Spat AUC: 0.7762 (Acc: 67.54%)
# Fold 1 | Epoch  80 | Spat AUC: 0.7765 (Acc: 69.30%)
# Fold 1 | Epoch  90 | Spat AUC: 0.8064 (Acc: 71.93%)
# Fold 1 | Epoch 100 | Spat AUC: 0.8290 (Acc: 74.56%)
# Fold 1 | Epoch 110 | Spat AUC: 0.8493 (Acc: 70.18%)
# Fold 1 | Epoch 120 | Spat AUC: 0.8393 (Acc: 74.56%)
# Fold 1 | Epoch 130 | Spat AUC: 0.8187 (Acc: 79.82%)
# Fold 1 | Epoch 140 | Spat AUC: 0.8045 (Acc: 69.30%)
# Fold 1 | Epoch 150 | Spat AUC: 0.7903 (Acc: 75.44%)
# Fold 1 | Epoch 160 | Spat AUC: 0.8206 (Acc: 70.18%)
# Fold 1 | Epoch 170 | Spat AUC: 0.7755 (Acc: 68.42%)
# Fold 1 | Epoch 180 | Spat AUC: 0.7865 (Acc: 69.30%)
# Fold 1 | Epoch 190 | Spat AUC: 0.8348 (Acc: 77.19%)
# Fold 1 | Epoch 200 | Spat AUC: 0.8187 (Acc: 72.81%)
# Fold 1 | Epoch 210 | Spat AUC: 0.8132 (Acc: 75.44%)
# Fold 1 | Epoch 220 | Spat AUC: 0.7749 (Acc: 64.04%)
# Fold 1 | Epoch 230 | Spat AUC: 0.8042 (Acc: 72.81%)
# Fold 1 | Epoch 240 | Spat AUC: 0.8438 (Acc: 66.67%)
# Fold 1 | Epoch 250 | Spat AUC: 0.8477 (Acc: 74.56%)
# Fold 1 | Epoch 260 | Spat AUC: 0.8390 (Acc: 76.32%)
# Fold 1 | Epoch 270 | Spat AUC: 0.8364 (Acc: 73.68%)
# Fold 1 | Epoch 280 | Spat AUC: 0.8341 (Acc: 75.44%)
# Fold 1 | Epoch 290 | Spat AUC: 0.8103 (Acc: 71.93%)
# Fold 1 | Epoch 300 | Spat AUC: 0.8145 (Acc: 72.81%)
# Fold 1 | Epoch 310 | Spat AUC: 0.8167 (Acc: 72.81%)
# Fold 1 | Epoch 320 | Spat AUC: 0.8151 (Acc: 71.93%)
# Fold 1 | Epoch 330 | Spat AUC: 0.8122 (Acc: 72.81%)
# Fold 1 | Epoch 340 | Spat AUC: 0.8161 (Acc: 64.91%)
# Fold 1 | Epoch 350 | Spat AUC: 0.8567 (Acc: 76.32%)
# Fold 1 | Epoch 360 | Spat AUC: 0.8380 (Acc: 71.93%)
# Fold 1 | Epoch 370 | Spat AUC: 0.8322 (Acc: 74.56%)
# Fold 1 | Epoch 380 | Spat AUC: 0.8254 (Acc: 76.32%)
# Fold 1 | Epoch 390 | Spat AUC: 0.8216 (Acc: 75.44%)
# Fold 1 | Epoch 400 | Spat AUC: 0.8203 (Acc: 75.44%)
# Fold 1 | Epoch 410 | Spat AUC: 0.8200 (Acc: 76.32%)
# Fold 1 | Epoch 420 | Spat AUC: 0.8196 (Acc: 75.44%)
# Fold 1 | Epoch 430 | Spat AUC: 0.8248 (Acc: 77.19%)
# Fold 1 | Epoch 440 | Spat AUC: 0.8235 (Acc: 77.19%)
# Fold 1 | Epoch 450 | Spat AUC: 0.8248 (Acc: 77.19%)
# Fold 1 | Epoch 460 | Spat AUC: 0.8254 (Acc: 76.32%)
# Fold 1 | Epoch 470 | Spat AUC: 0.8267 (Acc: 76.32%)
# Fold 1 | Epoch 480 | Spat AUC: 0.8274 (Acc: 74.56%)
# Fold 1 | Epoch 490 | Spat AUC: 0.8275 (Acc: 74.56%)
# Fold 1 | Epoch 500 | Spat AUC: 0.8271 (Acc: 74.56%)
# Starting Spatial ViT Fold 2...
# Fold 2 | Epoch  10 | Spat AUC: 0.4821 (Acc: 57.52%)
# Fold 2 | Epoch  20 | Spat AUC: 0.6167 (Acc: 58.41%)
# Fold 2 | Epoch  30 | Spat AUC: 0.7115 (Acc: 69.91%)
# Fold 2 | Epoch  40 | Spat AUC: 0.8074 (Acc: 74.34%)
# Fold 2 | Epoch  50 | Spat AUC: 0.8096 (Acc: 69.91%)
# Fold 2 | Epoch  60 | Spat AUC: 0.7824 (Acc: 72.57%)
# Fold 2 | Epoch  70 | Spat AUC: 0.7843 (Acc: 70.80%)
# Fold 2 | Epoch  80 | Spat AUC: 0.7756 (Acc: 67.26%)
# Fold 2 | Epoch  90 | Spat AUC: 0.7997 (Acc: 73.45%)
# Fold 2 | Epoch 100 | Spat AUC: 0.7407 (Acc: 69.03%)
# Fold 2 | Epoch 110 | Spat AUC: 0.7776 (Acc: 73.45%)
# Fold 2 | Epoch 120 | Spat AUC: 0.7705 (Acc: 66.37%)
# Fold 2 | Epoch 130 | Spat AUC: 0.7715 (Acc: 69.03%)
# Fold 2 | Epoch 140 | Spat AUC: 0.7766 (Acc: 70.80%)
# Fold 2 | Epoch 150 | Spat AUC: 0.7628 (Acc: 68.14%)
# Fold 2 | Epoch 160 | Spat AUC: 0.7644 (Acc: 69.03%)
# Fold 2 | Epoch 170 | Spat AUC: 0.7208 (Acc: 69.03%)
# Fold 2 | Epoch 180 | Spat AUC: 0.7753 (Acc: 68.14%)
# Fold 2 | Epoch 190 | Spat AUC: 0.7651 (Acc: 70.80%)
# Fold 2 | Epoch 200 | Spat AUC: 0.7907 (Acc: 74.34%)
# Fold 2 | Epoch 210 | Spat AUC: 0.7535 (Acc: 70.80%)
# Fold 2 | Epoch 220 | Spat AUC: 0.7484 (Acc: 65.49%)
# Fold 2 | Epoch 230 | Spat AUC: 0.7566 (Acc: 65.49%)
# Fold 2 | Epoch 240 | Spat AUC: 0.7572 (Acc: 67.26%)
# Fold 2 | Epoch 250 | Spat AUC: 0.7580 (Acc: 67.26%)
# Fold 2 | Epoch 260 | Spat AUC: 0.7522 (Acc: 67.26%)
# Fold 2 | Epoch 270 | Spat AUC: 0.7511 (Acc: 67.26%)
# Fold 2 | Epoch 280 | Spat AUC: 0.7492 (Acc: 67.26%)
# Fold 2 | Epoch 290 | Spat AUC: 0.7407 (Acc: 65.49%)
# Fold 2 | Epoch 300 | Spat AUC: 0.7373 (Acc: 62.83%)
# Fold 2 | Epoch 310 | Spat AUC: 0.7393 (Acc: 65.49%)
# Fold 2 | Epoch 320 | Spat AUC: 0.7423 (Acc: 65.49%)
# Fold 2 | Epoch 330 | Spat AUC: 0.7420 (Acc: 65.49%)
# Fold 2 | Epoch 340 | Spat AUC: 0.7482 (Acc: 68.14%)
# Fold 2 | Epoch 350 | Spat AUC: 0.7474 (Acc: 67.26%)
# Fold 2 | Epoch 360 | Spat AUC: 0.7479 (Acc: 65.49%)
# Fold 2 | Epoch 370 | Spat AUC: 0.7490 (Acc: 67.26%)
# Fold 2 | Epoch 380 | Spat AUC: 0.7481 (Acc: 67.26%)
# Fold 2 | Epoch 390 | Spat AUC: 0.7481 (Acc: 66.37%)
# Fold 2 | Epoch 400 | Spat AUC: 0.7478 (Acc: 67.26%)
# Fold 2 | Epoch 410 | Spat AUC: 0.7500 (Acc: 67.26%)
# Fold 2 | Epoch 420 | Spat AUC: 0.7487 (Acc: 67.26%)
# Fold 2 | Epoch 430 | Spat AUC: 0.7506 (Acc: 67.26%)
# Fold 2 | Epoch 440 | Spat AUC: 0.7492 (Acc: 67.26%)
# Fold 2 | Epoch 450 | Spat AUC: 0.7508 (Acc: 67.26%)
# Fold 2 | Epoch 460 | Spat AUC: 0.7505 (Acc: 67.26%)
# Fold 2 | Epoch 470 | Spat AUC: 0.7490 (Acc: 67.26%)
# Fold 2 | Epoch 480 | Spat AUC: 0.7462 (Acc: 67.26%)
# Fold 2 | Epoch 490 | Spat AUC: 0.7513 (Acc: 67.26%)
# Fold 2 | Epoch 500 | Spat AUC: 0.7518 (Acc: 67.26%)
# Starting Spatial ViT Fold 3...
# Fold 3 | Epoch  10 | Spat AUC: 0.6746 (Acc: 51.33%)
# Fold 3 | Epoch  20 | Spat AUC: 0.6611 (Acc: 51.33%)
# Fold 3 | Epoch  30 | Spat AUC: 0.7530 (Acc: 68.14%)
# Fold 3 | Epoch  40 | Spat AUC: 0.8013 (Acc: 75.22%)
# Fold 3 | Epoch  50 | Spat AUC: 0.7781 (Acc: 70.80%)
# Fold 3 | Epoch  60 | Spat AUC: 0.7762 (Acc: 67.26%)
# Fold 3 | Epoch  70 | Spat AUC: 0.7846 (Acc: 69.03%)
# Fold 3 | Epoch  80 | Spat AUC: 0.7843 (Acc: 67.26%)
# Fold 3 | Epoch  90 | Spat AUC: 0.7730 (Acc: 68.14%)
# Fold 3 | Epoch 100 | Spat AUC: 0.7944 (Acc: 67.26%)
# Fold 3 | Epoch 110 | Spat AUC: 0.7777 (Acc: 69.03%)
# Fold 3 | Epoch 120 | Spat AUC: 0.7906 (Acc: 68.14%)
# Fold 3 | Epoch 130 | Spat AUC: 0.7690 (Acc: 69.91%)
# Fold 3 | Epoch 140 | Spat AUC: 0.7599 (Acc: 68.14%)
# Fold 3 | Epoch 150 | Spat AUC: 0.7301 (Acc: 66.37%)
# Fold 3 | Epoch 160 | Spat AUC: 0.7113 (Acc: 62.83%)
# Fold 3 | Epoch 170 | Spat AUC: 0.7502 (Acc: 65.49%)
# Fold 3 | Epoch 180 | Spat AUC: 0.7194 (Acc: 66.37%)
# Fold 3 | Epoch 190 | Spat AUC: 0.7555 (Acc: 68.14%)
# Fold 3 | Epoch 200 | Spat AUC: 0.7661 (Acc: 69.91%)
# Fold 3 | Epoch 210 | Spat AUC: 0.7592 (Acc: 70.80%)
# Fold 3 | Epoch 220 | Spat AUC: 0.7674 (Acc: 68.14%)
# Fold 3 | Epoch 230 | Spat AUC: 0.7527 (Acc: 67.26%)
# Fold 3 | Epoch 240 | Spat AUC: 0.7514 (Acc: 64.60%)
# Fold 3 | Epoch 250 | Spat AUC: 0.7549 (Acc: 69.03%)
# Fold 3 | Epoch 260 | Spat AUC: 0.7549 (Acc: 69.91%)
# Fold 3 | Epoch 270 | Spat AUC: 0.7290 (Acc: 70.80%)
# Fold 3 | Epoch 280 | Spat AUC: 0.7257 (Acc: 67.26%)
# Fold 3 | Epoch 290 | Spat AUC: 0.7527 (Acc: 69.03%)
# Fold 3 | Epoch 300 | Spat AUC: 0.7599 (Acc: 67.26%)
# Fold 3 | Epoch 310 | Spat AUC: 0.7592 (Acc: 69.91%)
# Fold 3 | Epoch 320 | Spat AUC: 0.7522 (Acc: 70.80%)
# Fold 3 | Epoch 330 | Spat AUC: 0.7528 (Acc: 66.37%)
# Fold 3 | Epoch 340 | Spat AUC: 0.7520 (Acc: 68.14%)
# Fold 3 | Epoch 350 | Spat AUC: 0.6909 (Acc: 60.18%)
# Fold 3 | Epoch 360 | Spat AUC: 0.7386 (Acc: 63.72%)
# Fold 3 | Epoch 370 | Spat AUC: 0.7219 (Acc: 64.60%)
# Fold 3 | Epoch 380 | Spat AUC: 0.7213 (Acc: 63.72%)
# Fold 3 | Epoch 390 | Spat AUC: 0.7271 (Acc: 62.83%)
# Fold 3 | Epoch 400 | Spat AUC: 0.7284 (Acc: 62.83%)
# Fold 3 | Epoch 410 | Spat AUC: 0.7295 (Acc: 62.83%)
# Fold 3 | Epoch 420 | Spat AUC: 0.7301 (Acc: 62.83%)
# Fold 3 | Epoch 430 | Spat AUC: 0.7298 (Acc: 64.60%)
# Fold 3 | Epoch 440 | Spat AUC: 0.7180 (Acc: 62.83%)
# Fold 3 | Epoch 450 | Spat AUC: 0.7210 (Acc: 62.83%)
# Fold 3 | Epoch 460 | Spat AUC: 0.7229 (Acc: 62.83%)
# Fold 3 | Epoch 470 | Spat AUC: 0.7238 (Acc: 62.83%)
# Fold 3 | Epoch 480 | Spat AUC: 0.7251 (Acc: 62.83%)
# Fold 3 | Epoch 490 | Spat AUC: 0.7254 (Acc: 62.83%)
# Fold 3 | Epoch 500 | Spat AUC: 0.7254 (Acc: 62.83%)
# Starting Spatial ViT Fold 4...
# Fold 4 | Epoch  10 | Spat AUC: 0.6119 (Acc: 56.64%)
# Fold 4 | Epoch  20 | Spat AUC: 0.6521 (Acc: 57.52%)
# Fold 4 | Epoch  30 | Spat AUC: 0.7758 (Acc: 64.60%)
# Fold 4 | Epoch  40 | Spat AUC: 0.7969 (Acc: 75.22%)
# Fold 4 | Epoch  50 | Spat AUC: 0.8144 (Acc: 75.22%)
# Fold 4 | Epoch  60 | Spat AUC: 0.8001 (Acc: 74.34%)
# Fold 4 | Epoch  70 | Spat AUC: 0.7851 (Acc: 75.22%)
# Fold 4 | Epoch  80 | Spat AUC: 0.7688 (Acc: 73.45%)
# Fold 4 | Epoch  90 | Spat AUC: 0.7631 (Acc: 74.34%)
# Fold 4 | Epoch 100 | Spat AUC: 0.7812 (Acc: 72.57%)
# Fold 4 | Epoch 110 | Spat AUC: 0.7331 (Acc: 69.03%)
# Fold 4 | Epoch 120 | Spat AUC: 0.7474 (Acc: 70.80%)
# Fold 4 | Epoch 130 | Spat AUC: 0.7522 (Acc: 70.80%)
# Fold 4 | Epoch 140 | Spat AUC: 0.7548 (Acc: 69.91%)
# Fold 4 | Epoch 150 | Spat AUC: 0.8211 (Acc: 73.45%)
# Fold 4 | Epoch 160 | Spat AUC: 0.7567 (Acc: 69.91%)
# Fold 4 | Epoch 170 | Spat AUC: 0.7634 (Acc: 68.14%)
# Fold 4 | Epoch 180 | Spat AUC: 0.7672 (Acc: 69.03%)
# Fold 4 | Epoch 190 | Spat AUC: 0.7564 (Acc: 66.37%)
# Fold 4 | Epoch 200 | Spat AUC: 0.7452 (Acc: 67.26%)
# Fold 4 | Epoch 210 | Spat AUC: 0.8017 (Acc: 70.80%)
# Fold 4 | Epoch 220 | Spat AUC: 0.7969 (Acc: 73.45%)
# Fold 4 | Epoch 230 | Spat AUC: 0.7612 (Acc: 69.91%)
# Fold 4 | Epoch 240 | Spat AUC: 0.7841 (Acc: 71.68%)
# Fold 4 | Epoch 250 | Spat AUC: 0.7628 (Acc: 69.91%)
# Fold 4 | Epoch 260 | Spat AUC: 0.7510 (Acc: 69.03%)
# Fold 4 | Epoch 270 | Spat AUC: 0.7487 (Acc: 69.91%)
# Fold 4 | Epoch 280 | Spat AUC: 0.8047 (Acc: 69.91%)
# Fold 4 | Epoch 290 | Spat AUC: 0.7996 (Acc: 67.26%)
# Fold 4 | Epoch 300 | Spat AUC: 0.8023 (Acc: 69.03%)
# Fold 4 | Epoch 310 | Spat AUC: 0.7921 (Acc: 66.37%)
# Fold 4 | Epoch 320 | Spat AUC: 0.7943 (Acc: 67.26%)
# Fold 4 | Epoch 330 | Spat AUC: 0.7908 (Acc: 67.26%)
# Fold 4 | Epoch 340 | Spat AUC: 0.7690 (Acc: 69.91%)
# Fold 4 | Epoch 350 | Spat AUC: 0.7769 (Acc: 72.57%)
# Fold 4 | Epoch 360 | Spat AUC: 0.7733 (Acc: 72.57%)
# Fold 4 | Epoch 370 | Spat AUC: 0.7530 (Acc: 72.57%)
# Fold 4 | Epoch 380 | Spat AUC: 0.7710 (Acc: 74.34%)
# Fold 4 | Epoch 390 | Spat AUC: 0.7736 (Acc: 72.57%)
# Fold 4 | Epoch 400 | Spat AUC: 0.7717 (Acc: 71.68%)
# Fold 4 | Epoch 410 | Spat AUC: 0.7518 (Acc: 69.03%)
# Fold 4 | Epoch 420 | Spat AUC: 0.7561 (Acc: 69.91%)
# Fold 4 | Epoch 430 | Spat AUC: 0.7572 (Acc: 69.03%)
# Fold 4 | Epoch 440 | Spat AUC: 0.7580 (Acc: 69.91%)
# Fold 4 | Epoch 450 | Spat AUC: 0.7572 (Acc: 69.91%)
# Fold 4 | Epoch 460 | Spat AUC: 0.7573 (Acc: 69.91%)
# Fold 4 | Epoch 470 | Spat AUC: 0.7578 (Acc: 69.91%)
# Fold 4 | Epoch 480 | Spat AUC: 0.7581 (Acc: 69.91%)
# Fold 4 | Epoch 490 | Spat AUC: 0.7585 (Acc: 69.91%)
# Fold 4 | Epoch 500 | Spat AUC: 0.7585 (Acc: 69.91%)
# Starting Spatial ViT Fold 5...
# Fold 5 | Epoch  10 | Spat AUC: 0.6707 (Acc: 49.56%)
# Fold 5 | Epoch  20 | Spat AUC: 0.7719 (Acc: 49.56%)
# Fold 5 | Epoch  30 | Spat AUC: 0.7240 (Acc: 62.83%)
# Fold 5 | Epoch  40 | Spat AUC: 0.7979 (Acc: 64.60%)
# Fold 5 | Epoch  50 | Spat AUC: 0.7804 (Acc: 75.22%)
# Fold 5 | Epoch  60 | Spat AUC: 0.7873 (Acc: 70.80%)
# Fold 5 | Epoch  70 | Spat AUC: 0.7757 (Acc: 72.57%)
# Fold 5 | Epoch  80 | Spat AUC: 0.7466 (Acc: 68.14%)
# Fold 5 | Epoch  90 | Spat AUC: 0.7669 (Acc: 69.91%)
# Fold 5 | Epoch 100 | Spat AUC: 0.6920 (Acc: 64.60%)
# Fold 5 | Epoch 110 | Spat AUC: 0.7534 (Acc: 67.26%)
# Fold 5 | Epoch 120 | Spat AUC: 0.7829 (Acc: 73.45%)
# Fold 5 | Epoch 130 | Spat AUC: 0.7744 (Acc: 69.03%)
# Fold 5 | Epoch 140 | Spat AUC: 0.7732 (Acc: 64.60%)
# Fold 5 | Epoch 150 | Spat AUC: 0.7732 (Acc: 67.26%)
# Fold 5 | Epoch 160 | Spat AUC: 0.7669 (Acc: 70.80%)
# Fold 5 | Epoch 170 | Spat AUC: 0.7359 (Acc: 64.60%)
# Fold 5 | Epoch 180 | Spat AUC: 0.7547 (Acc: 69.03%)
# Fold 5 | Epoch 190 | Spat AUC: 0.7581 (Acc: 67.26%)
# Fold 5 | Epoch 200 | Spat AUC: 0.7577 (Acc: 67.26%)
# Fold 5 | Epoch 210 | Spat AUC: 0.7231 (Acc: 66.37%)
# Fold 5 | Epoch 220 | Spat AUC: 0.7306 (Acc: 65.49%)
# Fold 5 | Epoch 230 | Spat AUC: 0.7312 (Acc: 68.14%)
# Fold 5 | Epoch 240 | Spat AUC: 0.7312 (Acc: 68.14%)
# Fold 5 | Epoch 250 | Spat AUC: 0.7491 (Acc: 66.37%)
# Fold 5 | Epoch 260 | Spat AUC: 0.7616 (Acc: 68.14%)
# Fold 5 | Epoch 270 | Spat AUC: 0.7657 (Acc: 69.03%)
# Fold 5 | Epoch 280 | Spat AUC: 0.7654 (Acc: 69.03%)
# Fold 5 | Epoch 290 | Spat AUC: 0.7694 (Acc: 69.03%)
# Fold 5 | Epoch 300 | Spat AUC: 0.7685 (Acc: 69.03%)
# Fold 5 | Epoch 310 | Spat AUC: 0.7671 (Acc: 69.03%)
# Fold 5 | Epoch 320 | Spat AUC: 0.7320 (Acc: 67.26%)
# Fold 5 | Epoch 330 | Spat AUC: 0.7299 (Acc: 67.26%)
# Fold 5 | Epoch 340 | Spat AUC: 0.7334 (Acc: 65.49%)
# Fold 5 | Epoch 350 | Spat AUC: 0.7337 (Acc: 66.37%)
# Fold 5 | Epoch 360 | Spat AUC: 0.7318 (Acc: 67.26%)
# Fold 5 | Epoch 370 | Spat AUC: 0.7365 (Acc: 68.14%)
# Fold 5 | Epoch 380 | Spat AUC: 0.7351 (Acc: 68.14%)
# Fold 5 | Epoch 390 | Spat AUC: 0.7359 (Acc: 69.03%)
# Fold 5 | Epoch 400 | Spat AUC: 0.7365 (Acc: 69.03%)
# Fold 5 | Epoch 410 | Spat AUC: 0.7339 (Acc: 65.49%)
# Fold 5 | Epoch 420 | Spat AUC: 0.7368 (Acc: 68.14%)
# Fold 5 | Epoch 430 | Spat AUC: 0.7373 (Acc: 68.14%)
# Fold 5 | Epoch 440 | Spat AUC: 0.7370 (Acc: 68.14%)
# Fold 5 | Epoch 450 | Spat AUC: 0.7361 (Acc: 67.26%)
# Fold 5 | Epoch 460 | Spat AUC: 0.7357 (Acc: 67.26%)
# Fold 5 | Epoch 470 | Spat AUC: 0.7354 (Acc: 67.26%)
# Fold 5 | Epoch 480 | Spat AUC: 0.7354 (Acc: 67.26%)
# Fold 5 | Epoch 490 | Spat AUC: 0.7357 (Acc: 67.26%)
# Fold 5 | Epoch 500 | Spat AUC: 0.7354 (Acc: 67.26%)
# Spatial ViT parameters: 552,449

# %%
# Compact SpectralViT (~28k parameters)
PHYSICAL_BATCH_SIZE = 2
EFFECTIVE_BATCH_SIZE = 8
ACCUMULATION_STEPS = EFFECTIVE_BATCH_SIZE // PHYSICAL_BATCH_SIZE

compact_spatial_vit_history = {'compact_spatial_vit_loss': []}
oof_probs_spat_matched = []

for fold, (train_idx, test_idx) in enumerate(kf.split(X), 1):
    print(f"Starting Compact Spatial ViT Fold {fold}...")
    torch.cuda.empty_cache()
    
    # Data Preparation
    tr_vol = torch.from_numpy(X[train_idx]).unsqueeze(1).float()
    tr_y = torch.from_numpy(Y[train_idx]).float()
    ts_vol = torch.from_numpy(X[test_idx]).unsqueeze(1).float().to(device)
    ts_y = torch.from_numpy(Y[test_idx]).float().to(device)
    
    loader = DataLoader(TensorDataset(tr_vol, tr_y), batch_size=PHYSICAL_BATCH_SIZE, shuffle=True)
    
    # Configuration: embed_dim=12, heads=1, layers=1 to match SpectralViT complexity
    model = SpatialViTMatched(vol_size=VOL_SIZE, patch_size=12, embed_dim=12, n_heads=1, n_layers=1).to(device)
    
    opt = optim.AdamW(model.parameters(), lr=LR)
    sched = OneCycleLR(opt, max_lr=LR, steps_per_epoch=len(loader)//ACCUMULATION_STEPS, epochs=EPOCHS)
    crit = nn.BCEWithLogitsLoss()
    
    compact_spatial_vit_fold_losses = []
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss_compact_spatial_vit = 0
        for i, (b_vol, b_y) in enumerate(loader):
            b_vol, b_y = b_vol.to(device), b_y.to(device)
            
            logits = model(b_vol)
            loss = crit(logits, b_y) / ACCUMULATION_STEPS
            loss.backward()
            
            epoch_loss_compact_spatial_vit += loss.item() * ACCUMULATION_STEPS
            
            if (i + 1) % ACCUMULATION_STEPS == 0:
                opt.step()
                sched.step()
                opt.zero_grad()

        if (epoch + 1) % 10 == 0:
            model.eval()
            with torch.no_grad():
                test_probs = []
                for chunk in torch.split(ts_vol, PHYSICAL_BATCH_SIZE):
                    test_probs.append(torch.sigmoid(model(chunk)))
                probs = torch.cat(test_probs).cpu().numpy()
                auc = roc_auc_score(ts_y.cpu(), probs)
                print(f"Fold {fold} | Epoch {epoch+1:3d} | Matched AUC: {auc:.4f}")
        
        compact_spatial_vit_fold_losses.append(epoch_loss_compact_spatial_vit / len(loader))
    compact_spatial_vit_history['compact_spatial_vit_loss'].append(compact_spatial_vit_fold_losses)


    
    # Final Inference
    model.eval()
    with torch.no_grad():
        test_probs = []
        for chunk in torch.split(ts_vol, PHYSICAL_BATCH_SIZE):
            test_probs.append(torch.sigmoid(model(chunk)))
        oof_probs_spat_matched.append(torch.cat(test_probs).cpu().numpy())

params_match = sum(p.numel() for p in model.parameters())
print(f"\nMatched Spatial ViT parameters: {params_match:,}")
# Out:
# Starting Compact Spatial ViT Fold 1...
# Fold 1 | Epoch  10 | Matched AUC: 0.4238
# Fold 1 | Epoch  20 | Matched AUC: 0.4203
# Fold 1 | Epoch  30 | Matched AUC: 0.4554
# Fold 1 | Epoch  40 | Matched AUC: 0.4409
# Fold 1 | Epoch  50 | Matched AUC: 0.4461
# Fold 1 | Epoch  60 | Matched AUC: 0.4718
# Fold 1 | Epoch  70 | Matched AUC: 0.5027
# Fold 1 | Epoch  80 | Matched AUC: 0.5395
# Fold 1 | Epoch  90 | Matched AUC: 0.6548
# Fold 1 | Epoch 100 | Matched AUC: 0.7163
# Fold 1 | Epoch 110 | Matched AUC: 0.7233
# Fold 1 | Epoch 120 | Matched AUC: 0.6957
# Fold 1 | Epoch 130 | Matched AUC: 0.7056
# Fold 1 | Epoch 140 | Matched AUC: 0.7014
# Fold 1 | Epoch 150 | Matched AUC: 0.6757
# Fold 1 | Epoch 160 | Matched AUC: 0.6779
# Fold 1 | Epoch 170 | Matched AUC: 0.6386
# Fold 1 | Epoch 180 | Matched AUC: 0.6167
# Fold 1 | Epoch 190 | Matched AUC: 0.6374
# Fold 1 | Epoch 200 | Matched AUC: 0.6200
# Fold 1 | Epoch 210 | Matched AUC: 0.6145
# Fold 1 | Epoch 220 | Matched AUC: 0.6380
# Fold 1 | Epoch 230 | Matched AUC: 0.6464
# Fold 1 | Epoch 240 | Matched AUC: 0.6261
# Fold 1 | Epoch 250 | Matched AUC: 0.6235
# Fold 1 | Epoch 260 | Matched AUC: 0.6535
# Fold 1 | Epoch 270 | Matched AUC: 0.6206
# Fold 1 | Epoch 280 | Matched AUC: 0.6403
# Fold 1 | Epoch 290 | Matched AUC: 0.6412
# Fold 1 | Epoch 300 | Matched AUC: 0.6290
# Fold 1 | Epoch 310 | Matched AUC: 0.6573
# Fold 1 | Epoch 320 | Matched AUC: 0.6406
# Fold 1 | Epoch 330 | Matched AUC: 0.6201
# Fold 1 | Epoch 340 | Matched AUC: 0.6525
# Fold 1 | Epoch 350 | Matched AUC: 0.6325
# Fold 1 | Epoch 360 | Matched AUC: 0.6232
# Fold 1 | Epoch 370 | Matched AUC: 0.6557
# Fold 1 | Epoch 380 | Matched AUC: 0.6200
# Fold 1 | Epoch 390 | Matched AUC: 0.6245
# Fold 1 | Epoch 400 | Matched AUC: 0.6425
# Fold 1 | Epoch 410 | Matched AUC: 0.6415
# Fold 1 | Epoch 420 | Matched AUC: 0.6274
# Fold 1 | Epoch 430 | Matched AUC: 0.6409
# Fold 1 | Epoch 440 | Matched AUC: 0.6370
# Fold 1 | Epoch 450 | Matched AUC: 0.6396
# Fold 1 | Epoch 460 | Matched AUC: 0.6406
# Fold 1 | Epoch 470 | Matched AUC: 0.6406
# Fold 1 | Epoch 480 | Matched AUC: 0.6357
# Fold 1 | Epoch 490 | Matched AUC: 0.6390
# Fold 1 | Epoch 500 | Matched AUC: 0.6393
# Starting Compact Spatial ViT Fold 2...
# Fold 2 | Epoch  10 | Matched AUC: 0.5006
# Fold 2 | Epoch  20 | Matched AUC: 0.5564
# Fold 2 | Epoch  30 | Matched AUC: 0.6295
# Fold 2 | Epoch  40 | Matched AUC: 0.6138
# Fold 2 | Epoch  50 | Matched AUC: 0.6125
# Fold 2 | Epoch  60 | Matched AUC: 0.6978
# Fold 2 | Epoch  70 | Matched AUC: 0.6958
# Fold 2 | Epoch  80 | Matched AUC: 0.7170
# Fold 2 | Epoch  90 | Matched AUC: 0.6631
# Fold 2 | Epoch 100 | Matched AUC: 0.6583
# Fold 2 | Epoch 110 | Matched AUC: 0.6875
# Fold 2 | Epoch 120 | Matched AUC: 0.6647
# Fold 2 | Epoch 130 | Matched AUC: 0.6958
# Fold 2 | Epoch 140 | Matched AUC: 0.6804
# Fold 2 | Epoch 150 | Matched AUC: 0.7272
# Fold 2 | Epoch 160 | Matched AUC: 0.7135
# Fold 2 | Epoch 170 | Matched AUC: 0.7045
# Fold 2 | Epoch 180 | Matched AUC: 0.7093
# Fold 2 | Epoch 190 | Matched AUC: 0.6968
# Fold 2 | Epoch 200 | Matched AUC: 0.6955
# Fold 2 | Epoch 210 | Matched AUC: 0.7048
# Fold 2 | Epoch 220 | Matched AUC: 0.7061
# Fold 2 | Epoch 230 | Matched AUC: 0.7120
# Fold 2 | Epoch 240 | Matched AUC: 0.7168
# Fold 2 | Epoch 250 | Matched AUC: 0.7032
# Fold 2 | Epoch 260 | Matched AUC: 0.7022
# Fold 2 | Epoch 270 | Matched AUC: 0.7138
# Fold 2 | Epoch 280 | Matched AUC: 0.7199
# Fold 2 | Epoch 290 | Matched AUC: 0.7196
# Fold 2 | Epoch 300 | Matched AUC: 0.7093
# Fold 2 | Epoch 310 | Matched AUC: 0.7032
# Fold 2 | Epoch 320 | Matched AUC: 0.7026
# Fold 2 | Epoch 330 | Matched AUC: 0.7093
# Fold 2 | Epoch 340 | Matched AUC: 0.7093
# Fold 2 | Epoch 350 | Matched AUC: 0.7163
# Fold 2 | Epoch 360 | Matched AUC: 0.7006
# Fold 2 | Epoch 370 | Matched AUC: 0.6974
# Fold 2 | Epoch 380 | Matched AUC: 0.6949
# Fold 2 | Epoch 390 | Matched AUC: 0.6968
# Fold 2 | Epoch 400 | Matched AUC: 0.7000
# Fold 2 | Epoch 410 | Matched AUC: 0.6925
# Fold 2 | Epoch 420 | Matched AUC: 0.6986
# Fold 2 | Epoch 430 | Matched AUC: 0.6897
# Fold 2 | Epoch 440 | Matched AUC: 0.6859
# Fold 2 | Epoch 450 | Matched AUC: 0.6872
# Fold 2 | Epoch 460 | Matched AUC: 0.6830
# Fold 2 | Epoch 470 | Matched AUC: 0.6821
# Fold 2 | Epoch 480 | Matched AUC: 0.6833
# Fold 2 | Epoch 490 | Matched AUC: 0.6841
# Fold 2 | Epoch 500 | Matched AUC: 0.6846
# Starting Compact Spatial ViT Fold 3...
# Fold 3 | Epoch  10 | Matched AUC: 0.4266
# Fold 3 | Epoch  20 | Matched AUC: 0.4821
# Fold 3 | Epoch  30 | Matched AUC: 0.4966
# Fold 3 | Epoch  40 | Matched AUC: 0.5110
# Fold 3 | Epoch  50 | Matched AUC: 0.5166
# Fold 3 | Epoch  60 | Matched AUC: 0.5335
# Fold 3 | Epoch  70 | Matched AUC: 0.5621
# Fold 3 | Epoch  80 | Matched AUC: 0.6094
# Fold 3 | Epoch  90 | Matched AUC: 0.6354
# Fold 3 | Epoch 100 | Matched AUC: 0.6445
# Fold 3 | Epoch 110 | Matched AUC: 0.6392
# Fold 3 | Epoch 120 | Matched AUC: 0.6382
# Fold 3 | Epoch 130 | Matched AUC: 0.6461
# Fold 3 | Epoch 140 | Matched AUC: 0.6263
# Fold 3 | Epoch 150 | Matched AUC: 0.6257
# Fold 3 | Epoch 160 | Matched AUC: 0.6238
# Fold 3 | Epoch 170 | Matched AUC: 0.6150
# Fold 3 | Epoch 180 | Matched AUC: 0.6376
# Fold 3 | Epoch 190 | Matched AUC: 0.6241
# Fold 3 | Epoch 200 | Matched AUC: 0.6204
# Fold 3 | Epoch 210 | Matched AUC: 0.6304
# Fold 3 | Epoch 220 | Matched AUC: 0.6107
# Fold 3 | Epoch 230 | Matched AUC: 0.6019
# Fold 3 | Epoch 240 | Matched AUC: 0.6008
# Fold 3 | Epoch 250 | Matched AUC: 0.5994
# Fold 3 | Epoch 260 | Matched AUC: 0.6063
# Fold 3 | Epoch 270 | Matched AUC: 0.5843
# Fold 3 | Epoch 280 | Matched AUC: 0.6063
# Fold 3 | Epoch 290 | Matched AUC: 0.6042
# Fold 3 | Epoch 300 | Matched AUC: 0.5922
# Fold 3 | Epoch 310 | Matched AUC: 0.5853
# Fold 3 | Epoch 320 | Matched AUC: 0.5715
# Fold 3 | Epoch 330 | Matched AUC: 0.5928
# Fold 3 | Epoch 340 | Matched AUC: 0.5824
# Fold 3 | Epoch 350 | Matched AUC: 0.6000
# Fold 3 | Epoch 360 | Matched AUC: 0.6119
# Fold 3 | Epoch 370 | Matched AUC: 0.6013
# Fold 3 | Epoch 380 | Matched AUC: 0.5851
# Fold 3 | Epoch 390 | Matched AUC: 0.5815
# Fold 3 | Epoch 400 | Matched AUC: 0.5843
# Fold 3 | Epoch 410 | Matched AUC: 0.5779
# Fold 3 | Epoch 420 | Matched AUC: 0.5696
# Fold 3 | Epoch 430 | Matched AUC: 0.5788
# Fold 3 | Epoch 440 | Matched AUC: 0.5803
# Fold 3 | Epoch 450 | Matched AUC: 0.5661
# Fold 3 | Epoch 460 | Matched AUC: 0.5605
# Fold 3 | Epoch 470 | Matched AUC: 0.5677
# Fold 3 | Epoch 480 | Matched AUC: 0.5618
# Fold 3 | Epoch 490 | Matched AUC: 0.5652
# Fold 3 | Epoch 500 | Matched AUC: 0.5639
# Starting Compact Spatial ViT Fold 4...
# Fold 4 | Epoch  10 | Matched AUC: 0.4770
# Fold 4 | Epoch  20 | Matched AUC: 0.4895
# Fold 4 | Epoch  30 | Matched AUC: 0.5070
# Fold 4 | Epoch  40 | Matched AUC: 0.5386
# Fold 4 | Epoch  50 | Matched AUC: 0.5705
# Fold 4 | Epoch  60 | Matched AUC: 0.7015
# Fold 4 | Epoch  70 | Matched AUC: 0.7194
# Fold 4 | Epoch  80 | Matched AUC: 0.7372
# Fold 4 | Epoch  90 | Matched AUC: 0.7223
# Fold 4 | Epoch 100 | Matched AUC: 0.7350
# Fold 4 | Epoch 110 | Matched AUC: 0.7200
# Fold 4 | Epoch 120 | Matched AUC: 0.7168
# Fold 4 | Epoch 130 | Matched AUC: 0.7264
# Fold 4 | Epoch 140 | Matched AUC: 0.7235
# Fold 4 | Epoch 150 | Matched AUC: 0.6824
# Fold 4 | Epoch 160 | Matched AUC: 0.6869
# Fold 4 | Epoch 170 | Matched AUC: 0.6617
# Fold 4 | Epoch 180 | Matched AUC: 0.6901
# Fold 4 | Epoch 190 | Matched AUC: 0.6633
# Fold 4 | Epoch 200 | Matched AUC: 0.6665
# Fold 4 | Epoch 210 | Matched AUC: 0.6955
# Fold 4 | Epoch 220 | Matched AUC: 0.6489
# Fold 4 | Epoch 230 | Matched AUC: 0.6639
# Fold 4 | Epoch 240 | Matched AUC: 0.6716
# Fold 4 | Epoch 250 | Matched AUC: 0.7101
# Fold 4 | Epoch 260 | Matched AUC: 0.6614
# Fold 4 | Epoch 270 | Matched AUC: 0.6645
# Fold 4 | Epoch 280 | Matched AUC: 0.6792
# Fold 4 | Epoch 290 | Matched AUC: 0.6945
# Fold 4 | Epoch 300 | Matched AUC: 0.6403
# Fold 4 | Epoch 310 | Matched AUC: 0.6814
# Fold 4 | Epoch 320 | Matched AUC: 0.6786
# Fold 4 | Epoch 330 | Matched AUC: 0.6983
# Fold 4 | Epoch 340 | Matched AUC: 0.6872
# Fold 4 | Epoch 350 | Matched AUC: 0.6665
# Fold 4 | Epoch 360 | Matched AUC: 0.6881
# Fold 4 | Epoch 370 | Matched AUC: 0.6897
# Fold 4 | Epoch 380 | Matched AUC: 0.6787
# Fold 4 | Epoch 390 | Matched AUC: 0.6566
# Fold 4 | Epoch 400 | Matched AUC: 0.6834
# Fold 4 | Epoch 410 | Matched AUC: 0.6821
# Fold 4 | Epoch 420 | Matched AUC: 0.6996
# Fold 4 | Epoch 430 | Matched AUC: 0.6872
# Fold 4 | Epoch 440 | Matched AUC: 0.6735
# Fold 4 | Epoch 450 | Matched AUC: 0.6680
# Fold 4 | Epoch 460 | Matched AUC: 0.6722
# Fold 4 | Epoch 470 | Matched AUC: 0.6754
# Fold 4 | Epoch 480 | Matched AUC: 0.6757
# Fold 4 | Epoch 490 | Matched AUC: 0.6725
# Fold 4 | Epoch 500 | Matched AUC: 0.6719
# Starting Compact Spatial ViT Fold 5...
# Fold 5 | Epoch  10 | Matched AUC: 0.5943
# Fold 5 | Epoch  20 | Matched AUC: 0.6015
# Fold 5 | Epoch  30 | Matched AUC: 0.6159
# Fold 5 | Epoch  40 | Matched AUC: 0.6184
# Fold 5 | Epoch  50 | Matched AUC: 0.6181
# Fold 5 | Epoch  60 | Matched AUC: 0.6175
# Fold 5 | Epoch  70 | Matched AUC: 0.6278
# Fold 5 | Epoch  80 | Matched AUC: 0.6413
# Fold 5 | Epoch  90 | Matched AUC: 0.6510
# Fold 5 | Epoch 100 | Matched AUC: 0.6673
# Fold 5 | Epoch 110 | Matched AUC: 0.6692
# Fold 5 | Epoch 120 | Matched AUC: 0.6845
# Fold 5 | Epoch 130 | Matched AUC: 0.6341
# Fold 5 | Epoch 140 | Matched AUC: 0.6065
# Fold 5 | Epoch 150 | Matched AUC: 0.6363
# Fold 5 | Epoch 160 | Matched AUC: 0.6212
# Fold 5 | Epoch 170 | Matched AUC: 0.6140
# Fold 5 | Epoch 180 | Matched AUC: 0.5802
# Fold 5 | Epoch 190 | Matched AUC: 0.5999
# Fold 5 | Epoch 200 | Matched AUC: 0.5959
# Fold 5 | Epoch 210 | Matched AUC: 0.6018
# Fold 5 | Epoch 220 | Matched AUC: 0.5683
# Fold 5 | Epoch 230 | Matched AUC: 0.5235
# Fold 5 | Epoch 240 | Matched AUC: 0.5138
# Fold 5 | Epoch 250 | Matched AUC: 0.5501
# Fold 5 | Epoch 260 | Matched AUC: 0.5523
# Fold 5 | Epoch 270 | Matched AUC: 0.5545
# Fold 5 | Epoch 280 | Matched AUC: 0.5855
# Fold 5 | Epoch 290 | Matched AUC: 0.6034
# Fold 5 | Epoch 300 | Matched AUC: 0.5398
# Fold 5 | Epoch 310 | Matched AUC: 0.5498
# Fold 5 | Epoch 320 | Matched AUC: 0.5570
# Fold 5 | Epoch 330 | Matched AUC: 0.5439
# Fold 5 | Epoch 340 | Matched AUC: 0.5213
# Fold 5 | Epoch 350 | Matched AUC: 0.5326
# Fold 5 | Epoch 360 | Matched AUC: 0.5351
# Fold 5 | Epoch 370 | Matched AUC: 0.5363
# Fold 5 | Epoch 380 | Matched AUC: 0.5351
# Fold 5 | Epoch 390 | Matched AUC: 0.5470
# Fold 5 | Epoch 400 | Matched AUC: 0.5476
# Fold 5 | Epoch 410 | Matched AUC: 0.5379
# Fold 5 | Epoch 420 | Matched AUC: 0.5414
# Fold 5 | Epoch 430 | Matched AUC: 0.5442
# Fold 5 | Epoch 440 | Matched AUC: 0.5392
# Fold 5 | Epoch 450 | Matched AUC: 0.5351
# Fold 5 | Epoch 460 | Matched AUC: 0.5448
# Fold 5 | Epoch 470 | Matched AUC: 0.5404
# Fold 5 | Epoch 480 | Matched AUC: 0.5448
# Fold 5 | Epoch 490 | Matched AUC: 0.5414
# Fold 5 | Epoch 500 | Matched AUC: 0.5407
#
# Matched Spatial ViT parameters: 28,237

# %%
# Training
oof_probs_swin = []
kf = KFold(n_splits=5, shuffle=True, random_state=0)
swin_history = {'swin_loss': []}
for fold, (train_idx, test_idx) in enumerate(kf.split(X)):
    tr_vol = torch.from_numpy(X[train_idx]).unsqueeze(1).float()
    tr_y = torch.from_numpy(Y[train_idx]).float()
    ts_vol = torch.from_numpy(X[test_idx]).unsqueeze(1).float().to(device)
    ts_y = torch.from_numpy(Y[test_idx]).float().to(device)
    train_loader = DataLoader(BalancedDataset(tr_vol, tr_y), batch_size=BATCH_SIZE, shuffle=True)
    
    # img_size=96, patch_size=8, res=12, divisible by window_size=6
    m_swin = SwinTransformer(img_size=X.shape[-1], patch_size=8, window_size=6).to(device)
    optimizer = optim.AdamW(m_swin.parameters(), lr=1e-4,)
    criterion = nn.BCEWithLogitsLoss()

    print(f"Starting Swin Fold {fold+1}...")
    fold_swin_losses = []
    for epoch in range(1, EPOCHS + 1):
        m_swin.train()
        epoch_loss_swin = 0
        for b_vol, b_y in train_loader:
            b_vol, b_y = b_vol.to(device), b_y.to(device)
            optimizer.zero_grad()
            l_swin = criterion(m_swin(b_vol + torch.randn_like(b_vol)*0.01), b_y)
            l_swin.backward()
            optimizer.step()
            epoch_loss_swin += l_swin.item()
        
        # Save average epoch loss
        fold_swin_losses.append(epoch_loss_swin / len(train_loader))
    swin_history['swin_loss'].append(fold_swin_losses)

    with torch.no_grad():
        m_swin.eval()
        logits = m_swin(ts_vol)
        oof_probs_swin.append(torch.sigmoid(logits).cpu().numpy())
    
    del m_swin; gc.collect(); torch.cuda.empty_cache()

# Results
p_swin_final = np.concatenate(oof_probs_swin)
preds_swin = (p_swin_final > 0.5).astype(int)

params_swin = sum(p.numel() for p in
                   SwinTransformer(img_size=X.shape[-1], patch_size=8, window_size=6).to(device).parameters() 
                   if p.requires_grad)
print(f"Swin Parameters: {params_swin:,}")
# Out:
# Starting Swin Fold 1...
# Starting Swin Fold 2...
# Starting Swin Fold 3...

# %%
# U-net
unet_history = {'unet_loss': []}
oof_probs_unet = []

for fold, (train_idx, test_idx) in enumerate(kf.split(X)):
    print(f"Starting Attention U-Net Fold {fold+1}...")
    torch.cuda.empty_cache()
    
    # Data
    tr_vol = torch.from_numpy(X[train_idx]).unsqueeze(1).float()
    tr_y = torch.from_numpy(Y[train_idx]).float()
    ts_vol = torch.from_numpy(X[test_idx]).unsqueeze(1).float().to(device)
    ts_y = torch.from_numpy(Y[test_idx]).float().to(device)
    
    # Use your original BATCH_SIZE (e.g., 8) for speed
    train_loader = DataLoader(TensorDataset(tr_vol, tr_y), batch_size=BATCH_SIZE, shuffle=True)
    
    # Identical Model call
    m_unet = AttentionUNet(in_channels=1, base_channels=7).to(device)
    optimizer = optim.AdamW(m_unet.parameters(), lr=1e-4)
    criterion = nn.BCEWithLogitsLoss()

    fold_unet_losses = []
    for epoch in range(1, EPOCHS + 1):
        m_unet.train()
        epoch_loss_unet = 0
        for b_vol, b_y in train_loader:
            b_vol, b_y = b_vol.to(device), b_y.to(device)
            optimizer.zero_grad()
            loss = criterion(m_unet(b_vol), b_y)
            loss.backward()
            optimizer.step()
            epoch_loss_unet += loss.item()
        
        fold_unet_losses.append(epoch_loss_unet / len(train_loader))
    unet_history['unet_loss'].append(fold_unet_losses)

    # Fast Inference
    m_unet.eval()
    with torch.no_grad():
        # Using a loop for inference to prevent OOM on the test set
        test_probs = []
        for chunk in torch.split(ts_vol, PHYSICAL_BATCH_SIZE):
            test_probs.append(torch.sigmoid(m_unet(chunk)))
        oof_probs_unet.append(torch.cat(test_probs).cpu().numpy())

params_unet = sum(p.numel() for p in m_unet.parameters())
print(f"U-Net Parameters: {params_unet:,}")
# Out:
# Starting Attention U-Net Fold 1...
# Starting Attention U-Net Fold 2...
# Starting Attention U-Net Fold 3...
# Starting Attention U-Net Fold 4...
# Starting Attention U-Net Fold 5...
# U-Net Parameters: 14,382

# %%
seed_everything(0)

def plot_all_model_losses(spectral_vit_history, 
                          spatial_vit_history, 
                          compact_spatial_vit_history, 
                          unet_history, swin_history):
    combined = {**spectral_vit_history, **spatial_vit_history, **compact_spatial_vit_history, **unet_history, **swin_history}
    plt.figure(figsize=(12, 7))
    
    configs = [
            ('spectral_vit_loss', 'Spectral ViT', 'tab:blue', '-'),
            ('spatial_vit_loss', 'Spatial ViT (Heavy)', 'tab:orange', '--'), # Check this key too!
            ('compact_spatial_vit_loss', 'Spatial ViT (Matched)', 'tab:green', '--'),
            ('swin_loss', 'Swin ViT', 'tab:purple', '-.'),
            ('unet_loss', 'Attn U-Net', 'tab:red', ':'),
        ]
        
    for key, label, color, style in configs:
        if key in combined and len(combined[key]) > 0:
            data = np.array(combined[key])
            mean_loss = np.mean(data, axis=0)
            std_loss = np.std(data, axis=0)
            epochs = range(1, len(mean_loss) + 1)
            
            plt.plot(epochs, mean_loss, label=label, color=color, linestyle=style, lw=2)
            plt.fill_between(epochs, mean_loss - std_loss, mean_loss + std_loss, color=color, alpha=0.1)

    plt.title("Cross-Validated Training Loss: Model Comparison", fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Binary Cross-Entropy Loss")
    plt.xlim([1, EPOCHS])
    plt.ylim([0, 1])
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

plot_all_model_losses(spectral_vit_history, spatial_vit_history, compact_spatial_vit_history, unet_history, swin_history)

# %%
def get_metrics_array(y_true, y_probs):
    """Calculate metrics for a set of predictions."""
    preds = (y_probs > 0.5).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, preds).ravel()
    acc = (tp + tn) / len(y_true)
    sens = tp / (tp + fn) if (tp + fn) > 0 else 0
    spec = tn / (tn + fp) if (tn + fp) > 0 else 0
    auc = roc_auc_score(y_true, y_probs)
    return np.array([acc, sens, spec, auc])

# Compute overall metrics
y_final = np.concatenate(oof_y_true)
p_spec_final = np.concatenate(oof_probs_spec)
p_spat_final = np.concatenate(oof_probs_spat)
p_match_final = np.concatenate(oof_probs_spat_matched)
p_unet_final = np.concatenate(oof_probs_unet)

spec_metrics = get_metrics_array(y_final, p_spec_final)
spat_metrics = get_metrics_array(y_final, p_spat_final)
match_metrics = get_metrics_array(y_final, p_match_final)
unet_metrics = get_metrics_array(y_final, p_unet_final)

# Compute per-fold variation
spec_fold_metrics = [get_metrics_array(oof_y_true[f], oof_probs_spec[f]) for f in range(N_FOLDS)]
spat_fold_metrics = [get_metrics_array(oof_y_true[f], oof_probs_spat[f]) for f in range(N_FOLDS)]
match_fold_metrics = [get_metrics_array(oof_y_true[f], oof_probs_spat_matched[f]) for f in range(N_FOLDS)]
unet_fold_metrics = [get_metrics_array(oof_y_true[f], oof_probs_unet[f]) for f in range(N_FOLDS)]

spec_std = np.std(spec_fold_metrics, axis=0)
spat_std = np.std(spat_fold_metrics, axis=0)
match_std = np.std(match_fold_metrics, axis=0)
unet_std = np.std(unet_fold_metrics, axis=0)

# Print results with fixed alignment
col_width = 22
print("\n" + "="*110)
print(f"{'Metric':<15} | {'Spectral ViT':^{col_width}} | {'Spat-ViT (H)':^{col_width}} | {'Spat-ViT (M)':^{col_width}} | {'Attn U-Net':^{col_width}}")
print("-" * 110)

metric_names = ['Accuracy', 'Sensitivity', 'Specificity', 'AUC']
for i, name in enumerate(metric_names):
    spec_str  = f"{spec_metrics[i]:.3f} ± {spec_std[i]:.3f}"
    spat_str  = f"{spat_metrics[i]:.3f} ± {spat_std[i]:.3f}"
    match_str = f"{match_metrics[i]:.3f} ± {match_std[i]:.3f}"
    unet_str  = f"{unet_metrics[i]:.3f} ± {unet_std[i]:.3f}"
    print(f"{name:<15} | {spec_str:^{col_width}} | {spat_str:^{col_width}} | {match_str:^{col_width}} | {unet_str:^{col_width}}")

print("-" * 110)
print(f"{'Parameters':<15} | {params_spec:^{col_width},} | {params_spat:^{col_width},} | {params_match:^{col_width},} | {params_unet:^{col_width},}")
print("="*110)
# Out:
# ==============================================================================================================
# Metric          |      Spectral ViT      |      Spat-ViT (H)      |      Spat-ViT (M)      |       Attn U-Net
# --------------------------------------------------------------------------------------------------------------
# Accuracy        |     0.551 ± 0.041      |     0.560 ± 0.031      |     0.549 ± 0.042      |     0.551 ± 0.041
# Sensitivity     |     1.000 ± 0.000      |     1.000 ± 0.000      |     0.962 ± 0.083      |     1.000 ± 0.000
# Specificity     |     0.000 ± 0.000      |     0.020 ± 0.035      |     0.043 ± 0.080      |     0.000 ± 0.000
# AUC             |     0.474 ± 0.080      |     0.650 ± 0.038      |     0.507 ± 0.120      |     0.466 ± 0.106
# --------------------------------------------------------------------------------------------------------------
# Parameters      |         13,169         |        552,449         |         28,237         |         14,382
# ==============================================================================================================
